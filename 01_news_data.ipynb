# %% [markdown]
# <a href="https://colab.research.google.com/github/hui509/News_Crawler/blob/main/01_news_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests 
from bs4 import BeautifulSoup

# 利用 requests 對 API 來源發送一個請求
response = requests.get('https://udn.com/news/breaknews/1')
# 解析並取出內文
soup = BeautifulSoup(response.text,"html.parser")
# 定義news容器儲存資料
news = []

for link in soup.find_all('h3', class_='rounded-thumb__title')[:4]:
    news_url = link.a['href']
    news_response = requests.get('https://udn.com' + news_url)
    news_soup = BeautifulSoup(news_response.text,"html.parser")
    news_content = news_soup.find('div', class_='article-content__paragraph').text.strip().replace('\n', ' ')
    news.append(news_content)

print(news)
# Out:
# ['豪雨不斷，台中今早雨勢猛烈，弘光科技大學位於台灣大道六段斜坡處，有學生嘗試突破積水過馬路，現場2名校方警衛站在馬路旁，其中1名警衛人員伸出手想要協助撐傘的學生過馬路，未料學生一秒被強勁水勢沖走，當場「滑」下去，全身濕，一旁民眾以手機紀錄下畫面，上傳網路戲稱「弘光科大滑水道」，引發熱議。 \r 中央氣象局今針對台中市發布大雷雨即時訊息。台中市多處發生積淹水災情，有的水深超過半個輪胎高，居民出入不便。臉書社群「社會事群組」有網友發文，在弘光科技大學目睹過馬路的學生遭大量雨勢沖走，戲稱是「弘光科大滑水道」，引發網友討論。            \r 在地居民表示，由於弘光科技大學位於台灣大道六段，該處屬於斜坡，只要有豪雨降臨，上方高處雨勢都會沖刷下來，尤其機車騎士騎在積水的馬路上相當危險，雨量太多，就連行人徒步過馬路都很困難，需要格外注意安全。 \r 畫面可看到，弘光科大在校門口派駐4、5名警衛與校方人員，協助徒步師生安全過馬路，其中一名撐傘學生嘗試徒步過馬路，1名警衛伸出手想要協助，未料，馬路由高處往低處，傾瀉而下的雨水水勢強勁，直接將學生連人帶傘沖倒，校方警衛也愛莫能助。 \r 校門口多名警衛與校方人員逐一協助機車騎士，以牽機車徒步模式進入校園，避免機車在積水馬路上滑倒，造成事故。弘光科技大學有學生嘗試突破積水過馬路，未料一秒被強勁水勢沖走，當場「滑」下去，全身濕，有網友將影片上傳，戲稱「弘光科大滑水道」，引發熱議。圖／翻攝自臉書社群「社會事群組」弘光科技大學有學生嘗試突破積水過馬路，未料一秒被強勁水勢沖走，當場「滑」下去，全身濕，有網友將影片上傳，戲稱「弘光科大滑水道」，引發熱議。圖／翻攝自臉書社群「社會事群組」    梅雨 大雨特報 豪雨', '媒體人于美人今天表示，明天將舉辦記者會，宣布參選北市中正、萬華區立委。至於代表什麼黨籍參選？于辦不願透露，僅說「明天就會知道」。 \r 于美人表示，經過長時間反覆的自我叩問，已經完全確定了心中的答案。明天早上做說明，地點在西本願寺廣場前人行道，謝謝過去這段時間各位的